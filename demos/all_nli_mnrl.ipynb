# %%
# !git clone https://github.com/kddubey/mpnrl.git

# %%
# %cd mpnrl

# %%
# !pip install ".[demos]"

# %%
import os

from google.colab import userdata
import wandb

from run import run, Experiment

# %%
os.environ["WANDB_PROJECT"] = "mpnrl"
os.environ["WANDB_LOG_MODEL"] = "false"
wandb.login(key=userdata.get("WANDB_API_KEY"))
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: kddubey (kddubey-independent). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
experiment = Experiment(
    run_name="all-nli-mpnrl",
    loss="mpnrl",
    per_device_train_batch_size=128,
    dataset_name="sentence-transformers/all-nli",
    dataset_config="triplet",
    dataset_size_train=10_000,
)

# %%
run_id = run(experiment)
# Out:
# run_id='run-2024-12-23_02-05-39-all-nli-mpnrl'
# Results will be saved to run-2024-12-23_02-05-39-all-nli-mpnrl/dataset_reports/mpnrl/batch_size_128
#
#
# *********************** Loading train, val data ***********************
# README.md:   0%|          | 0.00/5.15k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/38.4M [00:00<?, ?B/s]
# dev-00000-of-00001.parquet:   0%|          | 0.00/782k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/810k [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/6609 [00:00<?, ? examples/s]
# ****************************** Training ******************************
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name distilroberta-base. Creating a new one with mean pooling.
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# ...

# %%
os.environ["RUN_ID"] = run_id

# %%
# !zip -r run.zip $RUN_ID
# Out:
#   adding: run-2024-12-23_02-05-39-all-nli-mpnrl/ (stored 0%)
#   adding: run-2024-12-23_02-05-39-all-nli-mpnrl/dataset_reports/ (stored 0%)
#   adding: run-2024-12-23_02-05-39-all-nli-mpnrl/dataset_reports/mpnrl/ (stored 0%)
#   adding: run-2024-12-23_02-05-39-all-nli-mpnrl/dataset_reports/mpnrl/batch_size_128/ (stored 0%)
#   adding: run-2024-12-23_02-05-39-all-nli-mpnrl/dataset_reports/mpnrl/batch_size_128/metrics.json (deflated 55%)
#   adding: run-2024-12-23_02-05-39-all-nli-mpnrl/dataset_reports/mpnrl/batch_size_128/experiment.json (deflated 55%)
#   adding: run-2024-12-23_02-05-39-all-nli-mpnrl/dataset_reports/mpnrl/batch_size_128/cuda_snapshot.pkl (deflated 98%)

# %%
from google.colab import files
files.download("run.zip")
